# %% [markdown]
# # R50-FPN PointRend
#
# Code where we prepare and run the R50-FPN PointRend model.

# %% [markdown]
# Opening the files stored at drive and check if they are being loaded correctly.

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

path = r'/content/drive/My Drive/MAI/OR/Fashionpedia/'

import zipfile

zip_ref = zipfile.ZipFile(path + "test.zip", 'r')
zip_ref.extractall("")
zip_ref.close()

zip_ref = zipfile.ZipFile(path + "val.zip", 'r')
zip_ref.extractall("")
zip_ref.close()

zip_ref = zipfile.ZipFile(path + "train.zip", 'r')
zip_ref.extractall("")
zip_ref.close()

zip_ref = zipfile.ZipFile(path + "seg_val.zip", 'r')
zip_ref.extractall("")
zip_ref.close()

zip_ref = zipfile.ZipFile(path + "seg_train.zip", 'r')
zip_ref.extractall("")
zip_ref.close()

print('Train contains:', len(os.listdir('/content/train/')), 'images')
print('Seg_train contains:',len(os.listdir('/content/seg_train/')), 'images')
print('Validation contains:',len(os.listdir('/content/val/')), 'images')
print('Seg_val contains:',len(os.listdir('/content/seg_val/')), 'images')
print('Test contains:',len(os.listdir('/content/test/')), 'images')
# Out:
# Mounted at /content/drive
# Train contains: 45623 images
# Seg_train contains: 45623 images
# Validation contains: 1158 images
# Seg_val contains: 1158 images
# Test contains: 2042 images

# %% [markdown]
# ## Importing and installing all the necessary libraries

# %%
# Install PyTorch
# !conda install pytorch==1.12.0 torchvision==0.13.0 torchaudio==0.12.0 cudatoolkit=11.3 -c pytorch
# Install mim
# !pip install -U openmim
# Install mmengine
# !mim install mmengine
# Install MMCV
# !mim install 'mmcv >= 2.0.0rc1'
# !rm -rf mmsegmentation
# !git clone -b main https://github.com/open-mmlab/mmsegmentation.git 
# %cd mmsegmentation
# !pip install -e .


import torch, torchvision
import mmseg
import mmcv
import mmengine
# Out:
# /bin/bash: conda: command not found
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openmim
#   Downloading openmim-0.3.7-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.3/51.3 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from openmim) (1.5.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from openmim) (13.3.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from openmim) (0.8.10)
# Requirement already satisfied: Click in /usr/local/lib/python3.9/dist-packages (from openmim) (8.1.3)
# Collecting model-index
#   Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from openmim) (2.27.1)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.9/dist-packages (from openmim) (23.0.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from model-index->openmim) (6.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.9/dist-packages (from model-index->openmim) (3.4.3)
# Collecting ordered-set
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->openmim) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas->openmim) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->openmim) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->openmim) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->openmim) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->openmim) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->openmim) (2022.12.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->openmim) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->openmim) (2.14.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->openmim) (1.16.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown->model-index->openmim) (6.4.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown->model-index->openmim) (3.15.0)
# Installing collected packages: ordered-set, colorama, model-index, openmim
# Successfully installed colorama-0.4.6 model-index-0.1.11 openmim-0.3.7 ordered-set-4.1.0
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmengine
#   Downloading mmengine-0.7.2-py3-none-any.whl (366 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.9/366.9 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from mmengine) (6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from mmengine) (2.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from mmengine) (1.22.4)
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from mmengine) (3.7.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from mmengine) (13.3.4)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.9/dist-packages (from mmengine) (4.7.0.72)
# Collecting yapf
#   Downloading yapf-0.33.0-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 kB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (5.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine) (2.8.2)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->mmengine) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->mmengine) (2.14.0)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from yapf->mmengine) (2.0.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->mmengine) (3.15.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.16.0)
# Installing collected packages: addict, yapf, mmengine
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# Successfully installed addict-2.4.0 mmengine-0.7.2 yapf-0.33.0
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmcv>=2.0.0rc1
#   Downloading https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/mmcv-2.0.0-cp39-cp39-manylinux1_x86_64.whl (74.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.4/74.4 MB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: yapf in /usr/local/lib/python3.9/dist-packages (from mmcv>=2.0.0rc1) (0.33.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from mmcv>=2.0.0rc1) (8.4.0)
# Requirement already satisfied: addict in /usr/local/lib/python3.9/dist-packages (from mmcv>=2.0.0rc1) (2.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from mmcv>=2.0.0rc1) (23.1)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.9/dist-packages (from mmcv>=2.0.0rc1) (4.7.0.72)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from mmcv>=2.0.0rc1) (1.22.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from mmcv>=2.0.0rc1) (6.0)
# Requirement already satisfied: mmengine>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from mmcv>=2.0.0rc1) (0.7.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from mmengine>=0.2.0->mmcv>=2.0.0rc1) (13.3.4)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from mmengine>=0.2.0->mmcv>=2.0.0rc1) (2.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from mmengine>=0.2.0->mmcv>=2.0.0rc1) (3.7.1)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.9/dist-packages (from yapf->mmcv>=2.0.0rc1) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (4.39.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->mmengine>=0.2.0->mmcv>=2.0.0rc1) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->mmengine>=0.2.0->mmcv>=2.0.0rc1) (2.14.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (3.15.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->mmengine>=0.2.0->mmcv>=2.0.0rc1) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.2.0->mmcv>=2.0.0rc1) (1.16.0)
# Installing collected packages: mmcv
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# Successfully installed mmcv-2.0.0
# Cloning into 'mmsegmentation'...
# remote: Enumerating objects: 14770, done.
# remote: Counting objects: 100% (357/357), done.
# remote: Compressing objects: 100% (267/267), done.
# remote: Total 14770 (delta 121), reused 204 (delta 83), pack-reused 14413
# Receiving objects: 100% (14770/14770), 20.12 MiB | 31.26 MiB/s, done.
# Resolving deltas: 100% (10424/10424), done.
# /content/mmsegmentation
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/mmsegmentation
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from mmsegmentation==1.0.0) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from mmsegmentation==1.0.0) (1.22.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from mmsegmentation==1.0.0) (23.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.9/dist-packages (from mmsegmentation==1.0.0) (0.7.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from mmsegmentation==1.0.0) (1.10.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmsegmentation==1.0.0) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmsegmentation==1.0.0) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmsegmentation==1.0.0) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmsegmentation==1.0.0) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmsegmentation==1.0.0) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmsegmentation==1.0.0) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmsegmentation==1.0.0) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->mmsegmentation==1.0.0) (1.0.7)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->mmsegmentation==1.0.0) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->mmsegmentation==1.0.0) (1.16.0)
# Installing collected packages: mmsegmentation
#   Running setup.py develop for mmsegmentation
# Successfully installed mmsegmentation-1.0.0

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-9e2b7377-7d2d-cf05-9929-64eff91eaac7)

# %% [markdown]
# ### Prepare the model
# Download the R101-FPN model and prepare it to receive the Fashionpedia dataset.

# %% [markdown]
# We need to convert the annotation into semantic map format as an image.

# %%
# define class and palette for better visualization
classes = ('Background', 'shirt, blouse','top, t-shirt, sweatshirt','sweater','cardigan','jacket', 'vest','pants','shorts','skirt', 'coat', 'dress', 'jumpsuit',
           'cape', 'glasses','hat','headband, hair accessory','tie', 'glove','watch','belt','leg warmer','tights, stockings','sock','shoe','bag, wallet','scarf',
           'umbrella','hood','collar','lapel', 'epaulette','sleeve', 'pocket', 'neckline','buckle','zipper','applique','bead','bow','flower','fringe','ribbon',
           'rivet', 'ruffle', 'sequin','tassel')
palette = [ [5, 5, 5],  [186, 20, 20],  [89, 227, 70],  [48, 150, 194],  [190, 41, 204],  [237, 155, 78],  [250, 237, 97],  [24, 76, 199],  [28, 91, 117],  
           [40, 158, 77],  [22, 77, 65],  [240, 73, 67],  [194, 70, 64],  [108, 181, 212],  [233, 238, 240],  [1, 6, 61],  [191, 2, 166],  [2, 191, 59], 
           [255, 185, 56],  [181, 178, 172],  [173, 113, 2],  [255, 255, 255],  [224, 224, 224],  [233, 247, 244],  [71, 66, 65],  [219, 153, 138],  
           [141, 138, 219],  [206, 138, 219],  [48, 150, 194],  [233, 250, 45],  [242, 224, 172],  [255, 192, 20],  [247, 242, 228],  [78, 186, 100],  
           [177, 250, 192],  [251, 255, 31],  [207, 207, 207],  [227, 52, 183],  [255, 139, 71],  [252, 49, 30],  [247, 104, 235],  [124, 252, 244],  
           [235, 69, 66],  [249, 255, 66],  [252, 255, 163],  [217, 217, 212],  [210, 212, 152]]

from mmseg.registry import DATASETS
from mmseg.datasets import BaseSegDataset

@DATASETS.register_module()
class FashionPediaDataset(BaseSegDataset):
  METAINFO = dict(classes = classes, palette = palette)
  def __init__(self, **kwargs):
    super().__init__(img_suffix='.jpg', seg_map_suffix='_seg.png', **kwargs)

# %%
# Download config and checkpoint files
# !mim download mmsegmentation --config pointrend_r50_4xb4-160k_ade20k-512x512 --dest .
# Out:
# processing pointrend_r50_4xb4-160k_ade20k-512x512...
# downloading ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 MiB 15.3 MB/s eta 0:00:00
# Successfully downloaded pointrend_r50_512x512_160k_ade20k_20200807_232644-ac3febf2.pth to /content/mmsegmentation
# Successfully dumped pointrend_r50_4xb4-160k_ade20k-512x512.py to /content/mmsegmentation

# %%
from mmengine import Config
cfg = Config.fromfile('configs/point_rend/pointrend_r50_4xb4-160k_ade20k-512x512.py')
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# norm_cfg = dict(type='SyncBN', requires_grad=True)
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(512, 512))
# model = dict(
#     type='CascadeEncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(512, 512)),
#     num_stages=2,
#     pretrained='open-mmlab://resnet50_v1c',
#     backbone=dict(
#         type='ResNetV1c',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         dilations=(1, 1, 1, 1),
#         strides=(1, 2, 2, 2),
#         norm_cfg=dict(type='SyncBN', requires_grad=True),
#         norm_eval=False,
#         style='pytorch',
#         contract_dilation=True),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=4),
#     decode_head=[
#         dict(
#             type='FPNHead',
#             in_channels=[256, 256, 256, 256],
#             in_index=[0, 1, 2, 3],
#             feature_strides=[4, 8, 16, 32],
#             channels=128,
#             dropout_ratio=-1,
#             num_classes=150,
#             norm_cfg=dict(type='SyncBN', requires_grad=True),
#             align_corners=False,
#             loss_decode=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#         dict(
#             type='PointHead',
#             in_channels=[256],
#             in_index=[0],
#             channels=256,
#             num_fcs=3,
#             coarse_pred_each_layer=True,
#             dropout_ratio=-1,
#             num_classes=150,
#             align_corners=False,
#             loss_decode=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0))
#     ],
#     train_cfg=dict(
#         num_points=2048, oversample_ratio=3, importance_sample_ratio=0.75),
#     test_cfg=dict(
#         mode='whole',
#         subdivision_steps=2,
#         subdivision_num_points=8196,
#         scale_factor=2))
# dataset_type = 'ADE20KDataset'
# data_root = 'data/ade/ADEChallengeData2016'
# crop_size = (512, 512)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', reduce_zero_label=True),
#     dict(
#         type='RandomResize',
#         scale=(2048, 512),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(512, 512), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(2048, 512), keep_ratio=True),
#     dict(type='LoadAnnotations', reduce_zero_label=True),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=4,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='ADE20KDataset',
#         data_root='data/ade/ADEChallengeData2016',
#         data_prefix=dict(
#             img_path='images/training', seg_map_path='annotations/training'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', reduce_zero_label=True),
#             dict(
#                 type='RandomResize',
#                 scale=(2048, 512),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(512, 512), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='ADE20KDataset',
#         data_root='data/ade/ADEChallengeData2016',
#         data_prefix=dict(
#             img_path='images/validation',
#             seg_map_path='annotations/validation'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 512), keep_ratio=True),
#             dict(type='LoadAnnotations', reduce_zero_label=True),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='ADE20KDataset',
#         data_root='data/ade/ADEChallengeData2016',
#         data_prefix=dict(
#             img_path='images/validation',
#             seg_map_path='annotations/validation'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(2048, 512), keep_ratio=True),
#             dict(type='LoadAnnotations', reduce_zero_label=True),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = None
# resume = False
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005),
#     clip_grad=None)
# param_scheduler = [
#     dict(type='LinearLR', by_epoch=False, start_factor=0.1, begin=0, end=200),
#     dict(
#         type='PolyLR',
#         eta_min=0.0001,
#         power=0.9,
#         begin=200,
#         end=160000,
#         by_epoch=False)
# ]
# train_cfg = dict(
#     type='IterBasedTrainLoop', max_iters=160000, val_interval=16000)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=50, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=16000),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))

# %%
data_root = '/content/'
data_prefix_train = dict(img_path='train', seg_map_path='seg_train')
data_prefix_val = dict(img_path='val', seg_map_path='seg_val')
data_prefix_test = dict(img_path='test')

resume_run = True

cfg.norm_cfg = dict(type='BN', requires_grad=True)
cfg.crop_size = (256, 256)
cfg.model.data_preprocessor.size = cfg.crop_size
cfg.model.backbone.norm_cfg = cfg.norm_cfg
cfg.model.decode_head[0].num_classes = 47
cfg.model.decode_head[1].num_classes = 47

# Modify dataset type and path
cfg.dataset_type = 'FashionPediaDataset'
cfg.data_root = data_root

cfg.train_dataloader.batch_size = 32


cfg.train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations'),
    dict(type='Resize', scale=(256, 256), keep_ratio=True),
    dict(type='PhotoMetricDistortion'),
    dict(type='RandomCrop', crop_size=cfg.crop_size, cat_max_ratio=0.75),
    dict(type='RandomFlip', prob=0.5),
    dict(type='PackSegInputs')
]

cfg.test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='Resize', scale=(256, 256), keep_ratio=True),
    dict(type='LoadAnnotations'),
    dict(type='PackSegInputs')
]


cfg.train_dataloader.dataset.type = cfg.dataset_type
cfg.train_dataloader.dataset.data_root = cfg.data_root
cfg.train_dataloader.dataset.data_prefix = data_prefix_train 
cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline

cfg.val_dataloader.dataset.type = cfg.dataset_type
cfg.val_dataloader.dataset.data_root = cfg.data_root
cfg.val_dataloader.dataset.data_prefix = data_prefix_val
cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline

cfg.test_dataloader = cfg.val_dataloader


# Set up working dir to save files and logs.
cfg.work_dir = './work_dirs/checkpoints'

if resume_run:
  cfg.resume = True
  cfg.load_from = '/content/drive/My Drive/MAI/OR/Fashionpedia/iter_18000.pth'

cfg.train_cfg.max_iters = 30000
cfg.train_cfg.val_interval = 500
cfg.default_hooks.logger.interval = 10
cfg.default_hooks.checkpoint.interval = 500

# Set seed to facilitate reproducing the result
cfg['randomness'] = dict(seed=0)

# Let's have a look at the final config used for training
print(f'Config:\n{cfg.pretty_text}')
# Out:
# Config:
# norm_cfg = dict(type='BN', requires_grad=True)
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(512, 512))
# model = dict(
#     type='CascadeEncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(256, 256)),
#     num_stages=2,
#     pretrained='open-mmlab://resnet101_v1c',
#     backbone=dict(
#         type='ResNetV1c',
#         depth=101,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         dilations=(1, 1, 1, 1),
#         strides=(1, 2, 2, 2),
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=False,
#         style='pytorch',
#         contract_dilation=True),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=4),
#     decode_head=[
#         dict(
#             type='FPNHead',
#             in_channels=[256, 256, 256, 256],
#             in_index=[0, 1, 2, 3],
#             feature_strides=[4, 8, 16, 32],
#             channels=128,
#             dropout_ratio=-1,
#             num_classes=47,
#             norm_cfg=dict(type='SyncBN', requires_grad=True),
#             align_corners=False,
#             loss_decode=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#         dict(
#             type='PointHead',
#             in_channels=[256],
#             in_index=[0],
#             channels=256,
#             num_fcs=3,
#             coarse_pred_each_layer=True,
#             dropout_ratio=-1,
#             num_classes=47,
#             align_corners=False,
#             loss_decode=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0))
#     ],
#     train_cfg=dict(
#         num_points=2048, oversample_ratio=3, importance_sample_ratio=0.75),
#     test_cfg=dict(
#         mode='whole',
#         subdivision_steps=2,
#         subdivision_num_points=8196,
#         scale_factor=2))
# dataset_type = 'FashionPediaDataset'
# data_root = '/content/'
# crop_size = (256, 256)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(type='Resize', scale=(256, 256), keep_ratio=True),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='RandomCrop', crop_size=(256, 256), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(256, 256), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=32,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='FashionPediaDataset',
#         data_root='/content/',
#         data_prefix=dict(img_path='train_mod', seg_map_path='seg_train_mod'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(type='Resize', scale=(256, 256), keep_ratio=True),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='RandomCrop', crop_size=(256, 256), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='FashionPediaDataset',
#         data_root='/content/',
#         data_prefix=dict(img_path='val', seg_map_path='seg_val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(256, 256), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='FashionPediaDataset',
#         data_root='/content/',
#         data_prefix=dict(img_path='val', seg_map_path='seg_val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(256, 256), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = '/content/drive/My Drive/MAI/OR/Fashionpedia/iter_19000.pth'
# resume = True
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005),
#     clip_grad=None)
# param_scheduler = [
#     dict(type='LinearLR', by_epoch=False, start_factor=0.1, begin=0, end=200),
#     dict(
#         type='PolyLR',
#         eta_min=0.0001,
#         power=0.9,
#         begin=200,
#         end=160000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=30000, val_interval=500)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=10, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=500),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# work_dir = './work_dirs/checkpoints'
# randomness = dict(seed=0)

# %% [markdown]
# ### Train the model

# %%
from mmengine.runner import Runner

runner = Runner.from_cfg(cfg)
# Out:
# 04/22 14:49:20 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 2.0.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.1+cu118
#     OpenCV: 4.7.0
#     MMEngine: 0.7.2
#
# Runtime environment:
#     cudnn_benchmark: True
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 04/22 14:49:21 - mmengine - INFO - Config:
# norm_cfg = dict(type='BN', requires_grad=True)
# data_preprocessor = dict(
#     type='SegDataPreProcessor',
#     mean=[123.675, 116.28, 103.53],
#     std=[58.395, 57.12, 57.375],
#     bgr_to_rgb=True,
#     pad_val=0,
#     seg_pad_val=255,
#     size=(512, 512))
# model = dict(
#     type='CascadeEncoderDecoder',
#     data_preprocessor=dict(
#         type='SegDataPreProcessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_val=0,
#         seg_pad_val=255,
#         size=(256, 256)),
#     num_stages=2,
#     pretrained='open-mmlab://resnet50_v1c',
#     backbone=dict(
#         type='ResNetV1c',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         dilations=(1, 1, 1, 1),
#         strides=(1, 2, 2, 2),
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=False,
#         style='pytorch',
#         contract_dilation=True),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=4),
#     decode_head=[
#         dict(
#             type='FPNHead',
#             in_channels=[256, 256, 256, 256],
#             in_index=[0, 1, 2, 3],
#             feature_strides=[4, 8, 16, 32],
#             channels=128,
#             dropout_ratio=-1,
#             num_classes=47,
#             norm_cfg=dict(type='SyncBN', requires_grad=True),
#             align_corners=False,
#             loss_decode=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0)),
#         dict(
#             type='PointHead',
#             in_channels=[256],
#             in_index=[0],
#             channels=256,
#             num_fcs=3,
#             coarse_pred_each_layer=True,
#             dropout_ratio=-1,
#             num_classes=47,
#             align_corners=False,
#             loss_decode=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0))
#     ],
#     train_cfg=dict(
#         num_points=2048, oversample_ratio=3, importance_sample_ratio=0.75),
#     test_cfg=dict(
#         mode='whole',
#         subdivision_steps=2,
#         subdivision_num_points=8196,
#         scale_factor=2))
# dataset_type = 'FashionPediaDataset'
# data_root = '/content/'
# crop_size = (256, 256)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(type='Resize', scale=(256, 256), keep_ratio=True),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='RandomCrop', crop_size=(256, 256), cat_max_ratio=0.75),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackSegInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='Resize', scale=(256, 256), keep_ratio=True),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs')
# ]
# img_ratios = [0.5, 0.75, 1.0, 1.25, 1.5, 1.75]
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale_factor': 0.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 0.75,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.0,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.25,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.5,
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale_factor': 1.75,
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 0.0,
#                         'direction': 'horizontal'
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 1.0,
#                         'direction': 'horizontal'
#                     }], [{
#                         'type': 'LoadAnnotations'
#                     }], [{
#                         'type': 'PackSegInputs'
#                     }]])
# ]
# train_dataloader = dict(
#     batch_size=32,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     dataset=dict(
#         type='FashionPediaDataset',
#         data_root='/content/',
#         data_prefix=dict(img_path='train', seg_map_path='seg_train'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(type='Resize', scale=(256, 256), keep_ratio=True),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='RandomCrop', crop_size=(256, 256), cat_max_ratio=0.75),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackSegInputs')
#         ]))
# val_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='FashionPediaDataset',
#         data_root='/content/',
#         data_prefix=dict(img_path='val', seg_map_path='seg_val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(256, 256), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# test_dataloader = dict(
#     batch_size=1,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='FashionPediaDataset',
#         data_root='/content/',
#         data_prefix=dict(img_path='val', seg_map_path='seg_val'),
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='Resize', scale=(256, 256), keep_ratio=True),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs')
#         ]))
# val_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# test_evaluator = dict(type='IoUMetric', iou_metrics=['mIoU'])
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='SegLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = '/content/drive/My Drive/MAI/OR/Fashionpedia/iter_18000.pth'
# resume = True
# tta_model = dict(type='SegTTAModel')
# optimizer = dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005)
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.01, momentum=0.9, weight_decay=0.0005),
#     clip_grad=None)
# param_scheduler = [
#     dict(type='LinearLR', by_epoch=False, start_factor=0.1, begin=0, end=200),
#     dict(
#         type='PolyLR',
#         eta_min=0.0001,
#         power=0.9,
#         begin=200,
#         end=160000,
#         by_epoch=False)
# ]
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=30000, val_interval=500)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=10, log_metric_by_epoch=False),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', by_epoch=False, interval=500),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='SegVisualizationHook'))
# work_dir = './work_dirs/checkpoints'
# randomness = dict(seed=0)
# /content/mmsegmentation/mmseg/models/backbones/resnet.py:431: UserWarning: DeprecationWarning: pretrained is a deprecated, please use "init_cfg" instead
#   warnings.warn('DeprecationWarning: pretrained is a deprecated, '
# /content/mmsegmentation/mmseg/models/builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# /content/mmsegmentation/mmseg/models/losses/cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# 04/22 14:49:27 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 04/22 14:49:27 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /content/mmsegmentation/mmseg/engine/hooks/visualization_hook.py:61: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '

# %%
# start training
runner.train()
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 04/22 14:49:30 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# 04/22 14:49:31 - mmengine - INFO - load model from: open-mmlab://resnet50_v1c
# 04/22 14:49:31 - mmengine - INFO - Loads checkpoint by openmmlab backend from path: open-mmlab://resnet50_v1c
# Downloading: "https://download.openmmlab.com/pretrain/third_party/resnet50_v1c-2cccc1ad.pth" to /root/.cache/torch/hub/checkpoints/resnet50_v1c-2cccc1ad.pth
# 04/22 14:49:37 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# Loads checkpoint by local backend from path: /content/drive/My Drive/MAI/OR/Fashionpedia/iter_18000.pth
# 04/22 14:49:41 - mmengine - INFO - Load checkpoint from /content/drive/My Drive/MAI/OR/Fashionpedia/iter_18000.pth
# 04/22 14:49:41 - mmengine - INFO - resumed epoch: 0, iter: 18000
# 04/22 14:49:41 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 04/22 14:49:41 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 04/22 14:49:41 - mmengine - INFO - Checkpoints will be saved to /content/mmsegmentation/work_dirs/checkpoints.
# 04/22 14:50:14 - mmengine - INFO - Iter(train) [18010/30000]  lr: 9.0012e-03  eta: 10:53:59  time: 3.2727  data_time: 0.0508  memory: 13725  loss: 0.3926  decode_0.loss_ce: 0.1452  decode_0.acc_seg: 90.2742  decode_1.pointloss_ce: 0.2474  decode_1.acc_point: 71.5774
# 04/22 14:50:22 - mmengine - INFO - Iter(train) [18020/30000]  lr: 9.0007e-03  eta: 6:52:33  time: 0.8597  data_time: 0.0688  memory: 6078  loss: 0.3558  decode_0.loss_ce: 0.1339  decode_0.acc_seg: 94.3087  decode_1.pointloss_ce: 0.2219  decode_1.acc_point: 81.9324
# 04/22 14:50:32 - mmengine - INFO - Iter(train) [18030/30000]  lr: 9.0001e-03  eta: 5:36:31  time: 0.9281  data_time: 0.1120  memory: 6078  loss: 0.3005  decode_0.loss_ce: 0.1127  decode_0.acc_seg: 94.5696  decode_1.pointloss_ce: 0.1878  decode_1.acc_point: 80.7657
# 04/22 14:50:40 - mmengine - INFO - Iter(train) [18040/30000]  lr: 8.9995e-03  eta: 4:55:15  time: 0.8642  data_time: 0.0594  memory: 6078  loss: 0.3372  decode_0.loss_ce: 0.1243  decode_0.acc_seg: 93.4920  decode_1.pointloss_ce: 0.2129  decode_1.acc_point: 76.6012
# 04/22 14:50:50 - mmengine - INFO - Iter(train) [18050/30000]  lr: 8.9990e-03  eta: 4:32:18  time: 0.9115  data_time: 0.0964  memory: 6078  loss: 0.2928  decode_0.loss_ce: 0.1079  decode_0.acc_seg: 96.0994  decode_1.pointloss_ce: 0.1849  decode_1.acc_point: 83.1742
# 04/22 14:50:58 - mmengine - INFO - Iter(train) [18060/30000]  lr: 8.9984e-03  eta: 4:15:00  time: 0.8524  data_time: 0.0539  memory: 6078  loss: 0.3301  decode_0.loss_ce: 0.1169  decode_0.acc_seg: 94.3496  decode_1.pointloss_ce: 0.2132  decode_1.acc_point: 79.2971
# 04/22 14:51:07 - mmengine - INFO - Iter(train) [18070/30000]  lr: 8.9979e-03  eta: 4:04:39  time: 0.9244  data_time: 0.0881  memory: 6078  loss: 0.3317  decode_0.loss_ce: 0.1216  decode_0.acc_seg: 94.6139  decode_1.pointloss_ce: 0.2101  decode_1.acc_point: 78.3068
# 04/22 14:51:16 - mmengine - INFO - Iter(train) [18080/30000]  lr: 8.9973e-03  eta: 3:55:43  time: 0.8790  data_time: 0.0725  memory: 6078  loss: 0.3422  decode_0.loss_ce: 0.1289  decode_0.acc_seg: 93.4887  decode_1.pointloss_ce: 0.2134  decode_1.acc_point: 76.8905
# 04/22 14:51:25 - mmengine - INFO - Iter(train) [18090/30000]  lr: 8.9967e-03  eta: 3:50:06  time: 0.9408  data_time: 0.1217  memory: 6078  loss: 0.3521  decode_0.loss_ce: 0.1321  decode_0.acc_seg: 94.4344  decode_1.pointloss_ce: 0.2200  decode_1.acc_point: 77.5131
# 04/22 14:51:34 - mmengine - INFO - Iter(train) [18100/30000]  lr: 8.9962e-03  eta: 3:44:18  time: 0.8771  data_time: 0.0620  memory: 6078  loss: 0.3257  decode_0.loss_ce: 0.1203  decode_0.acc_seg: 95.0435  decode_1.pointloss_ce: 0.2055  decode_1.acc_point: 80.7010
# 04/22 14:51:43 - mmengine - INFO - Iter(train) [18110/30000]  lr: 8.9956e-03  eta: 3:40:14  time: 0.9152  data_time: 0.0738  memory: 6078  loss: 0.3467  decode_0.loss_ce: 0.1214  decode_0.acc_seg: 95.4223  decode_1.pointloss_ce: 0.2252  decode_1.acc_point: 80.6499
# 04/22 14:51:52 - mmengine - INFO - Iter(train) [18120/30000]  lr: 8.9950e-03  eta: 3:36:17  time: 0.8828  data_time: 0.0587  memory: 6078  loss: 0.2958  decode_0.loss_ce: 0.1120  decode_0.acc_seg: 96.4620  decode_1.pointloss_ce: 0.1837  decode_1.acc_point: 84.6714
# 04/22 14:52:01 - mmengine - INFO - Iter(train) [18130/30000]  lr: 8.9945e-03  eta: 3:33:18  time: 0.9092  data_time: 0.0715  memory: 6078  loss: 0.3806  decode_0.loss_ce: 0.1481  decode_0.acc_seg: 94.9049  decode_1.pointloss_ce: 0.2325  decode_1.acc_point: 82.1450
# 04/22 14:52:10 - mmengine - INFO - Iter(train) [18140/30000]  lr: 8.9939e-03  eta: 3:30:50  time: 0.9153  data_time: 0.0814  memory: 6078  loss: 0.3201  decode_0.loss_ce: 0.1206  decode_0.acc_seg: 93.0107  decode_1.pointloss_ce: 0.1995  decode_1.acc_point: 75.1150
# 04/22 14:52:20 - mmengine - INFO - Iter(train) [18150/30000]  lr: 8.9933e-03  eta: 3:28:33  time: 0.9070  data_time: 0.0674  memory: 6078  loss: 0.3292  decode_0.loss_ce: 0.1283  decode_0.acc_seg: 95.2762  decode_1.pointloss_ce: 0.2008  decode_1.acc_point: 81.9601
# 04/22 14:52:29 - mmengine - INFO - Iter(train) [18160/30000]  lr: 8.9928e-03  eta: 3:26:37  time: 0.9142  data_time: 0.0698  memory: 6078  loss: 0.3219  decode_0.loss_ce: 0.1222  decode_0.acc_seg: 93.7417  decode_1.pointloss_ce: 0.1997  decode_1.acc_point: 77.7829
# 04/22 14:52:38 - mmengine - INFO - Iter(train) [18170/30000]  lr: 8.9922e-03  eta: 3:24:45  time: 0.9010  data_time: 0.0608  memory: 6078  loss: 0.3499  decode_0.loss_ce: 0.1360  decode_0.acc_seg: 93.6084  decode_1.pointloss_ce: 0.2139  decode_1.acc_point: 76.6892
# 04/22 14:52:47 - mmengine - INFO - Iter(train) [18180/30000]  lr: 8.9916e-03  eta: 3:23:37  time: 0.9504  data_time: 0.0938  memory: 6078  loss: 0.3208  decode_0.loss_ce: 0.1225  decode_0.acc_seg: 95.5304  decode_1.pointloss_ce: 0.1983  decode_1.acc_point: 84.0234
# 04/22 14:52:56 - mmengine - INFO - Iter(train) [18190/30000]  lr: 8.9911e-03  eta: 3:21:58  time: 0.8906  data_time: 0.0550  memory: 6078  loss: 0.3168  decode_0.loss_ce: 0.1214  decode_0.acc_seg: 95.3669  decode_1.pointloss_ce: 0.1955  decode_1.acc_point: 81.5610
# 04/22 14:53:06 - mmengine - INFO - Iter(train) [18200/30000]  lr: 8.9905e-03  eta: 3:21:14  time: 0.9699  data_time: 0.1086  memory: 6078  loss: 0.3295  decode_0.loss_ce: 0.1222  decode_0.acc_seg: 94.4287  decode_1.pointloss_ce: 0.2073  decode_1.acc_point: 77.8519
# 04/22 14:53:15 - mmengine - INFO - Iter(train) [18210/30000]  lr: 8.9900e-03  eta: 3:19:40  time: 0.8731  data_time: 0.0459  memory: 6078  loss: 0.3106  decode_0.loss_ce: 0.1199  decode_0.acc_seg: 94.1547  decode_1.pointloss_ce: 0.1907  decode_1.acc_point: 78.7794
# 04/22 14:53:24 - mmengine - INFO - Iter(train) [18220/30000]  lr: 8.9894e-03  eta: 3:19:02  time: 0.9653  data_time: 0.1051  memory: 6078  loss: 0.3468  decode_0.loss_ce: 0.1295  decode_0.acc_seg: 95.9003  decode_1.pointloss_ce: 0.2173  decode_1.acc_point: 85.1492
# 04/22 14:53:33 - mmengine - INFO - Iter(train) [18230/30000]  lr: 8.9888e-03  eta: 3:17:36  time: 0.8647  data_time: 0.0441  memory: 6078  loss: 0.3429  decode_0.loss_ce: 0.1309  decode_0.acc_seg: 95.6683  decode_1.pointloss_ce: 0.2119  decode_1.acc_point: 79.7446
# 04/22 14:53:43 - mmengine - INFO - Iter(train) [18240/30000]  lr: 8.9883e-03  eta: 3:17:06  time: 0.9669  data_time: 0.1003  memory: 6078  loss: 0.3269  decode_0.loss_ce: 0.1229  decode_0.acc_seg: 93.3531  decode_1.pointloss_ce: 0.2040  decode_1.acc_point: 78.3136
# 04/22 14:53:51 - mmengine - INFO - Iter(train) [18250/30000]  lr: 8.9877e-03  eta: 3:15:51  time: 0.8680  data_time: 0.0443  memory: 6078  loss: 0.3220  decode_0.loss_ce: 0.1303  decode_0.acc_seg: 93.2959  decode_1.pointloss_ce: 0.1917  decode_1.acc_point: 79.4735
# 04/22 14:54:01 - mmengine - INFO - Iter(train) [18260/30000]  lr: 8.9871e-03  eta: 3:15:27  time: 0.9692  data_time: 0.0990  memory: 6078  loss: 0.3160  decode_0.loss_ce: 0.1263  decode_0.acc_seg: 94.8378  decode_1.pointloss_ce: 0.1896  decode_1.acc_point: 81.5748
# 04/22 14:54:10 - mmengine - INFO - Iter(train) [18270/30000]  lr: 8.9866e-03  eta: 3:14:27  time: 0.8841  data_time: 0.0510  memory: 6078  loss: 0.3181  decode_0.loss_ce: 0.1191  decode_0.acc_seg: 96.4405  decode_1.pointloss_ce: 0.1990  decode_1.acc_point: 86.2123
# 04/22 14:54:19 - mmengine - INFO - Iter(train) [18280/30000]  lr: 8.9860e-03  eta: 3:14:00  time: 0.9538  data_time: 0.0876  memory: 6078  loss: 0.3510  decode_0.loss_ce: 0.1344  decode_0.acc_seg: 95.9155  decode_1.pointloss_ce: 0.2166  decode_1.acc_point: 83.0278
# 04/22 14:54:28 - mmengine - INFO - Iter(train) [18290/30000]  lr: 8.9854e-03  eta: 3:13:11  time: 0.8967  data_time: 0.0654  memory: 6078  loss: 0.3023  decode_0.loss_ce: 0.1150  decode_0.acc_seg: 94.6133  decode_1.pointloss_ce: 0.1873  decode_1.acc_point: 78.9825
# 04/22 14:54:38 - mmengine - INFO - Iter(train) [18300/30000]  lr: 8.9849e-03  eta: 3:12:40  time: 0.9354  data_time: 0.0834  memory: 6078  loss: 0.3966  decode_0.loss_ce: 0.1541  decode_0.acc_seg: 91.0663  decode_1.pointloss_ce: 0.2425  decode_1.acc_point: 71.2677
# 04/22 14:54:47 - mmengine - INFO - Iter(train) [18310/30000]  lr: 8.9843e-03  eta: 3:12:08  time: 0.9287  data_time: 0.0767  memory: 6078  loss: 0.3736  decode_0.loss_ce: 0.1439  decode_0.acc_seg: 93.5382  decode_1.pointloss_ce: 0.2297  decode_1.acc_point: 78.6898
# 04/22 14:54:56 - mmengine - INFO - Iter(train) [18320/30000]  lr: 8.9837e-03  eta: 3:11:35  time: 0.9234  data_time: 0.0770  memory: 6078  loss: 0.3645  decode_0.loss_ce: 0.1358  decode_0.acc_seg: 91.8947  decode_1.pointloss_ce: 0.2287  decode_1.acc_point: 70.6767
# 04/22 14:55:05 - mmengine - INFO - Iter(train) [18330/30000]  lr: 8.9832e-03  eta: 3:11:02  time: 0.9191  data_time: 0.0753  memory: 6078  loss: 0.3136  decode_0.loss_ce: 0.1229  decode_0.acc_seg: 93.0080  decode_1.pointloss_ce: 0.1906  decode_1.acc_point: 78.2173
# 04/22 14:55:14 - mmengine - INFO - Iter(train) [18340/30000]  lr: 8.9826e-03  eta: 3:10:28  time: 0.9097  data_time: 0.0632  memory: 6078  loss: 0.3171  decode_0.loss_ce: 0.1261  decode_0.acc_seg: 92.9831  decode_1.pointloss_ce: 0.1910  decode_1.acc_point: 72.2402
# 04/22 14:55:24 - mmengine - INFO - Iter(train) [18350/30000]  lr: 8.9821e-03  eta: 3:10:00  time: 0.9272  data_time: 0.0780  memory: 6078  loss: 0.3357  decode_0.loss_ce: 0.1333  decode_0.acc_seg: 93.7474  decode_1.pointloss_ce: 0.2024  decode_1.acc_point: 81.6995
# 04/22 14:55:33 - mmengine - INFO - Iter(train) [18360/30000]  lr: 8.9815e-03  eta: 3:09:25  time: 0.8996  data_time: 0.0608  memory: 6078  loss: 0.3140  decode_0.loss_ce: 0.1258  decode_0.acc_seg: 94.6369  decode_1.pointloss_ce: 0.1882  decode_1.acc_point: 78.2405
# 04/22 14:55:42 - mmengine - INFO - Iter(train) [18370/30000]  lr: 8.9809e-03  eta: 3:09:09  time: 0.9575  data_time: 0.1035  memory: 6078  loss: 0.3618  decode_0.loss_ce: 0.1361  decode_0.acc_seg: 92.6602  decode_1.pointloss_ce: 0.2257  decode_1.acc_point: 75.8686
# 04/22 14:55:51 - mmengine - INFO - Iter(train) [18380/30000]  lr: 8.9804e-03  eta: 3:08:34  time: 0.8939  data_time: 0.0623  memory: 6078  loss: 0.3315  decode_0.loss_ce: 0.1235  decode_0.acc_seg: 93.4155  decode_1.pointloss_ce: 0.2080  decode_1.acc_point: 74.3904
# 04/22 14:56:01 - mmengine - INFO - Iter(train) [18390/30000]  lr: 8.9798e-03  eta: 3:08:19  time: 0.9564  data_time: 0.0978  memory: 6078  loss: 0.3172  decode_0.loss_ce: 0.1209  decode_0.acc_seg: 94.9791  decode_1.pointloss_ce: 0.1963  decode_1.acc_point: 79.3093
# 04/22 14:56:10 - mmengine - INFO - Iter(train) [18400/30000]  lr: 8.9792e-03  eta: 3:07:42  time: 0.8788  data_time: 0.0512  memory: 6078  loss: 0.3410  decode_0.loss_ce: 0.1306  decode_0.acc_seg: 95.6818  decode_1.pointloss_ce: 0.2104  decode_1.acc_point: 84.5050
# 04/22 14:56:19 - mmengine - INFO - Iter(train) [18410/30000]  lr: 8.9787e-03  eta: 3:07:26  time: 0.9468  data_time: 0.0796  memory: 6078  loss: 0.3540  decode_0.loss_ce: 0.1319  decode_0.acc_seg: 94.8610  decode_1.pointloss_ce: 0.2222  decode_1.acc_point: 81.5922
# 04/22 14:56:28 - mmengine - INFO - Iter(train) [18420/30000]  lr: 8.9781e-03  eta: 3:06:49  time: 0.8720  data_time: 0.0497  memory: 6078  loss: 0.3247  decode_0.loss_ce: 0.1254  decode_0.acc_seg: 94.8755  decode_1.pointloss_ce: 0.1993  decode_1.acc_point: 78.8586
# 04/22 14:56:37 - mmengine - INFO - Iter(train) [18430/30000]  lr: 8.9775e-03  eta: 3:06:33  time: 0.9456  data_time: 0.0791  memory: 6078  loss: 0.3265  decode_0.loss_ce: 0.1258  decode_0.acc_seg: 95.0111  decode_1.pointloss_ce: 0.2006  decode_1.acc_point: 78.6063
# 04/22 14:56:46 - mmengine - INFO - Iter(train) [18440/30000]  lr: 8.9770e-03  eta: 3:05:57  time: 0.8679  data_time: 0.0435  memory: 6078  loss: 0.3473  decode_0.loss_ce: 0.1287  decode_0.acc_seg: 94.7119  decode_1.pointloss_ce: 0.2186  decode_1.acc_point: 78.9226
# 04/22 14:56:56 - mmengine - INFO - Iter(train) [18450/30000]  lr: 8.9764e-03  eta: 3:05:49  time: 0.9704  data_time: 0.0998  memory: 6078  loss: 0.3422  decode_0.loss_ce: 0.1286  decode_0.acc_seg: 94.6949  decode_1.pointloss_ce: 0.2136  decode_1.acc_point: 78.6305
# 04/22 14:57:04 - mmengine - INFO - Iter(train) [18460/30000]  lr: 8.9758e-03  eta: 3:05:15  time: 0.8690  data_time: 0.0453  memory: 6078  loss: 0.3270  decode_0.loss_ce: 0.1259  decode_0.acc_seg: 94.6349  decode_1.pointloss_ce: 0.2010  decode_1.acc_point: 80.2004
# 04/22 14:57:14 - mmengine - INFO - Iter(train) [18470/30000]  lr: 8.9753e-03  eta: 3:05:04  time: 0.9562  data_time: 0.0890  memory: 6078  loss: 0.3203  decode_0.loss_ce: 0.1288  decode_0.acc_seg: 95.2979  decode_1.pointloss_ce: 0.1914  decode_1.acc_point: 82.3276
# 04/22 14:57:23 - mmengine - INFO - Iter(train) [18480/30000]  lr: 8.9747e-03  eta: 3:04:40  time: 0.9039  data_time: 0.0636  memory: 6078  loss: 0.3697  decode_0.loss_ce: 0.1343  decode_0.acc_seg: 92.9615  decode_1.pointloss_ce: 0.2353  decode_1.acc_point: 74.6324
# 04/22 14:57:32 - mmengine - INFO - Iter(train) [18490/30000]  lr: 8.9742e-03  eta: 3:04:24  time: 0.9329  data_time: 0.0801  memory: 6078  loss: 0.3707  decode_0.loss_ce: 0.1392  decode_0.acc_seg: 94.7904  decode_1.pointloss_ce: 0.2315  decode_1.acc_point: 78.4555
# 04/22 14:57:41 - mmengine - INFO - Iter(train) [18500/30000]  lr: 8.9736e-03  eta: 3:04:02  time: 0.9099  data_time: 0.0680  memory: 6078  loss: 0.3553  decode_0.loss_ce: 0.1369  decode_0.acc_seg: 95.7635  decode_1.pointloss_ce: 0.2184  decode_1.acc_point: 78.7345
# 04/22 14:57:41 - mmengine - INFO - Saving checkpoint at 18500 iterations
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Streaming output truncated to the last 5000 lines.
# 04/22 15:06:42 - mmengine - INFO - Iter(val) [ 200/1158]    eta: 0:00:28  time: 0.0270  data_time: 0.0035  memory: 383
# 04/22 15:06:42 - mmengine - INFO - Iter(val) [ 210/1158]    eta: 0:00:27  time: 0.0269  data_time: 0.0035  memory: 406
# 04/22 15:06:43 - mmengine - INFO - Iter(val) [ 220/1158]    eta: 0:00:27  time: 0.0287  data_time: 0.0035  memory: 435
# 04/22 15:06:43 - mmengine - INFO - Iter(val) [ 230/1158]    eta: 0:00:27  time: 0.0276  data_time: 0.0037  memory: 403
# 04/22 15:06:43 - mmengine - INFO - Iter(val) [ 240/1158]    eta: 0:00:26  time: 0.0286  data_time: 0.0037  memory: 416
# 04/22 15:06:44 - mmengine - INFO - Iter(val) [ 250/1158]    eta: 0:00:26  time: 0.0365  data_time: 0.0060  memory: 404
# 04/22 15:06:44 - mmengine - INFO - Iter(val) [ 260/1158]    eta: 0:00:27  time: 0.0475  data_time: 0.0100  memory: 461
# 04/22 15:06:44 - mmengine - INFO - Iter(val) [ 270/1158]    eta: 0:00:27  time: 0.0448  data_time: 0.0097  memory: 402
# 04/22 15:06:45 - mmengine - INFO - Iter(val) [ 280/1158]    eta: 0:00:27  time: 0.0450  data_time: 0.0112  memory: 402
# 04/22 15:06:45 - mmengine - INFO - Iter(val) [ 290/1158]    eta: 0:00:27  time: 0.0441  data_time: 0.0085  memory: 395
# 04/22 15:06:46 - mmengine - INFO - Iter(val) [ 300/1158]    eta: 0:00:27  time: 0.0466  data_time: 0.0114  memory: 462
# 04/22 15:06:46 - mmengine - INFO - Iter(val) [ 310/1158]    eta: 0:00:27  time: 0.0463  data_time: 0.0097  memory: 396
# 04/22 15:06:47 - mmengine - INFO - Iter(val) [ 320/1158]    eta: 0:00:27  time: 0.0454  data_time: 0.0103  memory: 385
# 04/22 15:06:47 - mmengine - INFO - Iter(val) [ 330/1158]    eta: 0:00:27  time: 0.0509  data_time: 0.0111  memory: 412
# 04/22 15:06:48 - mmengine - INFO - Iter(val) [ 340/1158]    eta: 0:00:27  time: 0.0475  data_time: 0.0103  memory: 414
# 04/22 15:06:48 - mmengine - INFO - Iter(val) [ 350/1158]    eta: 0:00:27  time: 0.0492  data_time: 0.0093  memory: 383
# 04/22 15:06:49 - mmengine - INFO - Iter(val) [ 360/1158]    eta: 0:00:27  time: 0.0469  data_time: 0.0088  memory: 462
# 04/22 15:06:49 - mmengine - INFO - Iter(val) [ 370/1158]    eta: 0:00:27  time: 0.0461  data_time: 0.0081  memory: 428
# 04/22 15:06:50 - mmengine - INFO - Iter(val) [ 380/1158]    eta: 0:00:27  time: 0.0423  data_time: 0.0087  memory: 383
# 04/22 15:06:50 - mmengine - INFO - Iter(val) [ 390/1158]    eta: 0:00:27  time: 0.0456  data_time: 0.0089  memory: 414
# 04/22 15:06:51 - mmengine - INFO - Iter(val) [ 400/1158]    eta: 0:00:27  time: 0.0484  data_time: 0.0105  memory: 461
# 04/22 15:06:51 - mmengine - INFO - Iter(val) [ 410/1158]    eta: 0:00:26  time: 0.0373  data_time: 0.0092  memory: 414
# 04/22 15:06:51 - mmengine - INFO - Iter(val) [ 420/1158]    eta: 0:00:26  time: 0.0300  data_time: 0.0055  memory: 383
# 04/22 15:06:52 - mmengine - INFO - Iter(val) [ 430/1158]    eta: 0:00:25  time: 0.0287  data_time: 0.0040  memory: 462
# 04/22 15:06:52 - mmengine - INFO - Iter(val) [ 440/1158]    eta: 0:00:25  time: 0.0301  data_time: 0.0044  memory: 456
# 04/22 15:06:52 - mmengine - INFO - Iter(val) [ 450/1158]    eta: 0:00:24  time: 0.0285  data_time: 0.0039  memory: 424
# 04/22 15:06:52 - mmengine - INFO - Iter(val) [ 460/1158]    eta: 0:00:24  time: 0.0296  data_time: 0.0051  memory: 388
# 04/22 15:06:53 - mmengine - INFO - Iter(val) [ 470/1158]    eta: 0:00:24  time: 0.0281  data_time: 0.0039  memory: 402
# 04/22 15:06:53 - mmengine - INFO - Iter(val) [ 480/1158]    eta: 0:00:23  time: 0.0311  data_time: 0.0067  memory: 383
# 04/22 15:06:53 - mmengine - INFO - Iter(val) [ 490/1158]    eta: 0:00:23  time: 0.0299  data_time: 0.0049  memory: 462
# 04/22 15:06:54 - mmengine - INFO - Iter(val) [ 500/1158]    eta: 0:00:22  time: 0.0291  data_time: 0.0044  memory: 403
# 04/22 15:06:54 - mmengine - INFO - Iter(val) [ 510/1158]    eta: 0:00:22  time: 0.0333  data_time: 0.0068  memory: 387
# 04/22 15:06:54 - mmengine - INFO - Iter(val) [ 520/1158]    eta: 0:00:22  time: 0.0292  data_time: 0.0046  memory: 402
# 04/22 15:06:55 - mmengine - INFO - Iter(val) [ 530/1158]    eta: 0:00:21  time: 0.0283  data_time: 0.0040  memory: 395
# 04/22 15:06:55 - mmengine - INFO - Iter(val) [ 540/1158]    eta: 0:00:21  time: 0.0282  data_time: 0.0040  memory: 462
# 04/22 15:06:55 - mmengine - INFO - Iter(val) [ 550/1158]    eta: 0:00:20  time: 0.0320  data_time: 0.0061  memory: 462
# 04/22 15:06:55 - mmengine - INFO - Iter(val) [ 560/1158]    eta: 0:00:20  time: 0.0296  data_time: 0.0036  memory: 461
# 04/22 15:06:56 - mmengine - INFO - Iter(val) [ 570/1158]    eta: 0:00:20  time: 0.0278  data_time: 0.0039  memory: 428
# 04/22 15:06:56 - mmengine - INFO - Iter(val) [ 580/1158]    eta: 0:00:19  time: 0.0284  data_time: 0.0037  memory: 404
# 04/22 15:06:56 - mmengine - INFO - Iter(val) [ 590/1158]    eta: 0:00:19  time: 0.0278  data_time: 0.0035  memory: 383
# 04/22 15:06:57 - mmengine - INFO - Iter(val) [ 600/1158]    eta: 0:00:18  time: 0.0280  data_time: 0.0041  memory: 383
# 04/22 15:06:57 - mmengine - INFO - Iter(val) [ 610/1158]    eta: 0:00:18  time: 0.0294  data_time: 0.0040  memory: 402
# 04/22 15:06:57 - mmengine - INFO - Iter(val) [ 620/1158]    eta: 0:00:18  time: 0.0301  data_time: 0.0048  memory: 462
# 04/22 15:06:57 - mmengine - INFO - Iter(val) [ 630/1158]    eta: 0:00:17  time: 0.0282  data_time: 0.0039  memory: 383
# 04/22 15:06:58 - mmengine - INFO - Iter(val) [ 640/1158]    eta: 0:00:17  time: 0.0289  data_time: 0.0040  memory: 383
# 04/22 15:06:58 - mmengine - INFO - Iter(val) [ 650/1158]    eta: 0:00:17  time: 0.0298  data_time: 0.0054  memory: 420
# 04/22 15:06:58 - mmengine - INFO - Iter(val) [ 660/1158]    eta: 0:00:16  time: 0.0281  data_time: 0.0037  memory: 402
# 04/22 15:06:59 - mmengine - INFO - Iter(val) [ 670/1158]    eta: 0:00:16  time: 0.0278  data_time: 0.0038  memory: 382
# 04/22 15:06:59 - mmengine - INFO - Iter(val) [ 680/1158]    eta: 0:00:15  time: 0.0282  data_time: 0.0038  memory: 394
# 04/22 15:06:59 - mmengine - INFO - Iter(val) [ 690/1158]    eta: 0:00:15  time: 0.0316  data_time: 0.0051  memory: 424
# 04/22 15:06:59 - mmengine - INFO - Iter(val) [ 700/1158]    eta: 0:00:15  time: 0.0291  data_time: 0.0045  memory: 460
# 04/22 15:07:00 - mmengine - INFO - Iter(val) [ 710/1158]    eta: 0:00:14  time: 0.0277  data_time: 0.0034  memory: 402
# 04/22 15:07:00 - mmengine - INFO - Iter(val) [ 720/1158]    eta: 0:00:14  time: 0.0299  data_time: 0.0047  memory: 427
# 04/22 15:07:00 - mmengine - INFO - Iter(val) [ 730/1158]    eta: 0:00:14  time: 0.0292  data_time: 0.0038  memory: 413
# 04/22 15:07:01 - mmengine - INFO - Iter(val) [ 740/1158]    eta: 0:00:13  time: 0.0508  data_time: 0.0236  memory: 383
# 04/22 15:07:01 - mmengine - INFO - Iter(val) [ 750/1158]    eta: 0:00:13  time: 0.0473  data_time: 0.0084  memory: 461
# 04/22 15:07:02 - mmengine - INFO - Iter(val) [ 760/1158]    eta: 0:00:13  time: 0.0469  data_time: 0.0095  memory: 414
# 04/22 15:07:02 - mmengine - INFO - Iter(val) [ 770/1158]    eta: 0:00:13  time: 0.0465  data_time: 0.0108  memory: 391
# 04/22 15:07:03 - mmengine - INFO - Iter(val) [ 780/1158]    eta: 0:00:12  time: 0.0465  data_time: 0.0114  memory: 458
# 04/22 15:07:03 - mmengine - INFO - Iter(val) [ 790/1158]    eta: 0:00:12  time: 0.0439  data_time: 0.0105  memory: 383
# 04/22 15:07:04 - mmengine - INFO - Iter(val) [ 800/1158]    eta: 0:00:12  time: 0.0517  data_time: 0.0096  memory: 462
# 04/22 15:07:04 - mmengine - INFO - Iter(val) [ 810/1158]    eta: 0:00:11  time: 0.0443  data_time: 0.0110  memory: 428
# 04/22 15:07:05 - mmengine - INFO - Iter(val) [ 820/1158]    eta: 0:00:11  time: 0.0406  data_time: 0.0093  memory: 414
# 04/22 15:07:05 - mmengine - INFO - Iter(val) [ 830/1158]    eta: 0:00:11  time: 0.0446  data_time: 0.0085  memory: 414
# 04/22 15:07:06 - mmengine - INFO - Iter(val) [ 840/1158]    eta: 0:00:11  time: 0.0485  data_time: 0.0113  memory: 402
# 04/22 15:07:06 - mmengine - INFO - Iter(val) [ 850/1158]    eta: 0:00:10  time: 0.0475  data_time: 0.0091  memory: 417
# 04/22 15:07:06 - mmengine - INFO - Iter(val) [ 860/1158]    eta: 0:00:10  time: 0.0449  data_time: 0.0079  memory: 408
# 04/22 15:07:07 - mmengine - INFO - Iter(val) [ 870/1158]    eta: 0:00:10  time: 0.0493  data_time: 0.0114  memory: 383
# 04/22 15:07:07 - mmengine - INFO - Iter(val) [ 880/1158]    eta: 0:00:09  time: 0.0479  data_time: 0.0086  memory: 441
# 04/22 15:07:08 - mmengine - INFO - Iter(val) [ 890/1158]    eta: 0:00:09  time: 0.0464  data_time: 0.0098  memory: 414
# 04/22 15:07:08 - mmengine - INFO - Iter(val) [ 900/1158]    eta: 0:00:09  time: 0.0480  data_time: 0.0092  memory: 402
# 04/22 15:07:09 - mmengine - INFO - Iter(val) [ 910/1158]    eta: 0:00:08  time: 0.0341  data_time: 0.0059  memory: 462
# 04/22 15:07:09 - mmengine - INFO - Iter(val) [ 920/1158]    eta: 0:00:08  time: 0.0288  data_time: 0.0044  memory: 383
# 04/22 15:07:09 - mmengine - INFO - Iter(val) [ 930/1158]    eta: 0:00:08  time: 0.0303  data_time: 0.0055  memory: 383
# 04/22 15:07:10 - mmengine - INFO - Iter(val) [ 940/1158]    eta: 0:00:07  time: 0.0303  data_time: 0.0055  memory: 395
# 04/22 15:07:10 - mmengine - INFO - Iter(val) [ 950/1158]    eta: 0:00:07  time: 0.0273  data_time: 0.0035  memory: 461
# 04/22 15:07:10 - mmengine - INFO - Iter(val) [ 960/1158]    eta: 0:00:06  time: 0.0303  data_time: 0.0065  memory: 433
# 04/22 15:07:11 - mmengine - INFO - Iter(val) [ 970/1158]    eta: 0:00:06  time: 0.0312  data_time: 0.0053  memory: 461
# 04/22 15:07:11 - mmengine - INFO - Iter(val) [ 980/1158]    eta: 0:00:06  time: 0.0293  data_time: 0.0051  memory: 414
# 04/22 15:07:11 - mmengine - INFO - Iter(val) [ 990/1158]    eta: 0:00:05  time: 0.0299  data_time: 0.0047  memory: 462
# 04/22 15:07:11 - mmengine - INFO - Iter(val) [1000/1158]    eta: 0:00:05  time: 0.0276  data_time: 0.0041  memory: 383
# 04/22 15:07:12 - mmengine - INFO - Iter(val) [1010/1158]    eta: 0:00:05  time: 0.0279  data_time: 0.0039  memory: 416
# 04/22 15:07:12 - mmengine - INFO - Iter(val) [1020/1158]    eta: 0:00:04  time: 0.0276  data_time: 0.0036  memory: 461
# 04/22 15:07:12 - mmengine - INFO - Iter(val) [1030/1158]    eta: 0:00:04  time: 0.0271  data_time: 0.0038  memory: 414
# 04/22 15:07:13 - mmengine - INFO - Iter(val) [1040/1158]    eta: 0:00:04  time: 0.0299  data_time: 0.0056  memory: 457
# 04/22 15:07:13 - mmengine - INFO - Iter(val) [1050/1158]    eta: 0:00:03  time: 0.0288  data_time: 0.0049  memory: 408
# 04/22 15:07:13 - mmengine - INFO - Iter(val) [1060/1158]    eta: 0:00:03  time: 0.0283  data_time: 0.0046  memory: 383
# 04/22 15:07:13 - mmengine - INFO - Iter(val) [1070/1158]    eta: 0:00:03  time: 0.0282  data_time: 0.0039  memory: 461
# 04/22 15:07:14 - mmengine - INFO - Iter(val) [1080/1158]    eta: 0:00:02  time: 0.0289  data_time: 0.0048  memory: 383
# 04/22 15:07:14 - mmengine - INFO - Iter(val) [1090/1158]    eta: 0:00:02  time: 0.0277  data_time: 0.0041  memory: 382
# 04/22 15:07:14 - mmengine - INFO - Iter(val) [1100/1158]    eta: 0:00:01  time: 0.0295  data_time: 0.0047  memory: 414
# 04/22 15:07:15 - mmengine - INFO - Iter(val) [1110/1158]    eta: 0:00:01  time: 0.0309  data_time: 0.0056  memory: 383
# 04/22 15:07:15 - mmengine - INFO - Iter(val) [1120/1158]    eta: 0:00:01  time: 0.0290  data_time: 0.0036  memory: 461
# 04/22 15:07:15 - mmengine - INFO - Iter(val) [1130/1158]    eta: 0:00:00  time: 0.0289  data_time: 0.0042  memory: 461
# 04/22 15:07:15 - mmengine - INFO - Iter(val) [1140/1158]    eta: 0:00:00  time: 0.0282  data_time: 0.0040  memory: 428
# 04/22 15:07:16 - mmengine - INFO - Iter(val) [1150/1158]    eta: 0:00:00  time: 0.0309  data_time: 0.0056  memory: 461
# 04/22 15:07:16 - mmengine - INFO - per class results:
# 04/22 15:07:16 - mmengine - INFO -
# +--------------------------+-------+-------+
# |          Class           |  IoU  |  Acc  |
# +--------------------------+-------+-------+
# |        Background        | 97.04 | 99.12 |
# |      shirt, blouse       | 30.24 |  43.2 |
# | top, t-shirt, sweatshirt | 50.72 | 68.13 |
# |         sweater          |  7.15 |  7.16 |
# |         cardigan         |  0.19 |  0.28 |
# |          jacket          | 33.31 | 57.71 |
# |           vest           |  0.27 |  0.29 |
# |          pants           |  63.3 | 77.06 |
# |          shorts          | 47.78 | 77.12 |
# |          skirt           | 42.33 | 58.47 |
# |           coat           | 39.03 | 63.06 |
# |          dress           | 66.03 | 77.14 |
# |         jumpsuit         | 13.59 | 19.21 |
# |           cape           | 14.43 | 15.88 |
# |         glasses          |  36.7 | 39.91 |
# |           hat            | 43.13 | 53.34 |
# | headband, hair accessory | 14.16 |  15.7 |
# |           tie            | 20.93 | 34.67 |
# |          glove           |  0.28 |  0.28 |
# |          watch           |  0.0  |  0.0  |
# |           belt           | 12.53 | 15.98 |
# |        leg warmer        |  0.0  |  0.0  |
# |    tights, stockings     | 34.25 | 42.42 |
# |           sock           |  0.0  |  0.0  |
# |           shoe           | 49.54 | 61.95 |
# |       bag, wallet        | 37.09 | 49.48 |
# |          scarf           | 10.37 |  11.9 |
# |         umbrella         | 69.42 | 74.28 |
# |           hood           |  2.45 |  2.98 |
# |          collar          | 17.17 | 26.78 |
# |          lapel           | 22.25 | 27.15 |
# |        epaulette         |  0.0  |  0.0  |
# |          sleeve          | 58.99 | 73.87 |
# |          pocket          |  7.18 |  8.68 |
# |         neckline         | 10.34 |  11.9 |
# |          buckle          |  0.0  |  0.0  |
# |          zipper          |  0.0  |  0.0  |
# |         applique         |  0.95 |  1.1  |
# |           bead           |  5.55 |  5.77 |
# |           bow            |  0.0  |  0.0  |
# |          flower          |  0.0  |  0.0  |
# |          fringe          |  2.32 |  2.41 |
# |          ribbon          |  0.0  |  0.0  |
# |          rivet           |  0.0  |  0.0  |
# |          ruffle          | 27.99 | 36.98 |
# |          sequin          |  0.0  |  0.0  |
# |          tassel          |  0.0  |  0.0  |
# +--------------------------+-------+-------+
# 04/22 15:07:16 - mmengine - INFO - Iter(val) [1158/1158]    aAcc: 94.0000  mIoU: 21.0400  mAcc: 26.8400  data_time: 0.0037  time: 0.0246
# 04/22 15:07:26 - mmengine - INFO - Iter(train) [19010/30000]  lr: 8.9448e-03  eta: 2:52:04  time: 0.9607  data_time: 0.1145  memory: 6078  loss: 0.3899  decode_0.loss_ce: 0.1451  decode_0.acc_seg: 94.6083  decode_1.pointloss_ce: 0.2448  decode_1.acc_point: 80.8250
# 04/22 15:07:34 - mmengine - INFO - Iter(train) [19020/30000]  lr: 8.9442e-03  eta: 2:51:49  time: 0.8813  data_time: 0.0649  memory: 6078  loss: 0.3483  decode_0.loss_ce: 0.1295  decode_0.acc_seg: 94.5617  decode_1.pointloss_ce: 0.2188  decode_1.acc_point: 81.9313
# 04/22 15:07:44 - mmengine - INFO - Iter(train) [19030/30000]  lr: 8.9437e-03  eta: 2:51:41  time: 0.9533  data_time: 0.1014  memory: 6078  loss: 0.3877  decode_0.loss_ce: 0.1428  decode_0.acc_seg: 93.3809  decode_1.pointloss_ce: 0.2449  decode_1.acc_point: 77.3243
# 04/22 15:07:53 - mmengine - INFO - Iter(train) [19040/30000]  lr: 8.9431e-03  eta: 2:51:24  time: 0.8683  data_time: 0.0579  memory: 6078  loss: 0.3853  decode_0.loss_ce: 0.1457  decode_0.acc_seg: 95.5559  decode_1.pointloss_ce: 0.2396  decode_1.acc_point: 83.6153
# 04/22 15:08:02 - mmengine - INFO - Iter(train) [19050/30000]  lr: 8.9425e-03  eta: 2:51:16  time: 0.9515  data_time: 0.0985  memory: 6078  loss: 0.3953  decode_0.loss_ce: 0.1575  decode_0.acc_seg: 94.6052  decode_1.pointloss_ce: 0.2379  decode_1.acc_point: 79.9521
# 04/22 15:08:11 - mmengine - INFO - Iter(train) [19060/30000]  lr: 8.9420e-03  eta: 2:50:59  time: 0.8675  data_time: 0.0538  memory: 6078  loss: 0.3846  decode_0.loss_ce: 0.1502  decode_0.acc_seg: 92.6139  decode_1.pointloss_ce: 0.2344  decode_1.acc_point: 75.1060
# 04/22 15:08:20 - mmengine - INFO - Iter(train) [19070/30000]  lr: 8.9414e-03  eta: 2:50:52  time: 0.9628  data_time: 0.1039  memory: 6078  loss: 0.3678  decode_0.loss_ce: 0.1326  decode_0.acc_seg: 95.8651  decode_1.pointloss_ce: 0.2352  decode_1.acc_point: 85.3579
# 04/22 15:08:29 - mmengine - INFO - Iter(train) [19080/30000]  lr: 8.9408e-03  eta: 2:50:36  time: 0.8722  data_time: 0.0569  memory: 6078  loss: 0.3507  decode_0.loss_ce: 0.1312  decode_0.acc_seg: 94.8488  decode_1.pointloss_ce: 0.2196  decode_1.acc_point: 78.8754
# 04/22 15:08:39 - mmengine - INFO - Iter(train) [19090/30000]  lr: 8.9403e-03  eta: 2:50:29  time: 0.9572  data_time: 0.1028  memory: 6078  loss: 0.3037  decode_0.loss_ce: 0.1196  decode_0.acc_seg: 95.3119  decode_1.pointloss_ce: 0.1841  decode_1.acc_point: 82.3277
# 04/22 15:08:47 - mmengine - INFO - Iter(train) [19100/30000]  lr: 8.9397e-03  eta: 2:50:12  time: 0.8629  data_time: 0.0509  memory: 6078  loss: 0.4084  decode_0.loss_ce: 0.1526  decode_0.acc_seg: 93.5560  decode_1.pointloss_ce: 0.2558  decode_1.acc_point: 81.2059
# 04/22 15:08:57 - mmengine - INFO - Iter(train) [19110/30000]  lr: 8.9392e-03  eta: 2:50:07  time: 0.9767  data_time: 0.1179  memory: 6078  loss: 0.3630  decode_0.loss_ce: 0.1338  decode_0.acc_seg: 95.3391  decode_1.pointloss_ce: 0.2291  decode_1.acc_point: 82.4570
# 04/22 15:09:06 - mmengine - INFO - Iter(train) [19120/30000]  lr: 8.9386e-03  eta: 2:49:49  time: 0.8529  data_time: 0.0470  memory: 6078  loss: 0.3839  decode_0.loss_ce: 0.1344  decode_0.acc_seg: 95.1754  decode_1.pointloss_ce: 0.2495  decode_1.acc_point: 82.8113
# 04/22 15:09:15 - mmengine - INFO - Iter(train) [19130/30000]  lr: 8.9380e-03  eta: 2:49:42  time: 0.9604  data_time: 0.1123  memory: 6078  loss: 0.3575  decode_0.loss_ce: 0.1276  decode_0.acc_seg: 94.7808  decode_1.pointloss_ce: 0.2299  decode_1.acc_point: 79.8150
# 04/22 15:09:24 - mmengine - INFO - Iter(train) [19140/30000]  lr: 8.9375e-03  eta: 2:49:25  time: 0.8536  data_time: 0.0454  memory: 6078  loss: 0.3723  decode_0.loss_ce: 0.1418  decode_0.acc_seg: 93.1531  decode_1.pointloss_ce: 0.2305  decode_1.acc_point: 76.8154
# 04/22 15:09:33 - mmengine - INFO - Iter(train) [19150/30000]  lr: 8.9369e-03  eta: 2:49:19  time: 0.9723  data_time: 0.1172  memory: 6078  loss: 0.3846  decode_0.loss_ce: 0.1432  decode_0.acc_seg: 94.1241  decode_1.pointloss_ce: 0.2414  decode_1.acc_point: 80.2055
# 04/22 15:09:42 - mmengine - INFO - Iter(train) [19160/30000]  lr: 8.9363e-03  eta: 2:49:02  time: 0.8620  data_time: 0.0504  memory: 6078  loss: 0.3595  decode_0.loss_ce: 0.1364  decode_0.acc_seg: 94.8268  decode_1.pointloss_ce: 0.2231  decode_1.acc_point: 78.9581
# 04/22 15:09:52 - mmengine - INFO - Iter(train) [19170/30000]  lr: 8.9358e-03  eta: 2:48:56  time: 0.9664  data_time: 0.1084  memory: 6078  loss: 0.3857  decode_0.loss_ce: 0.1418  decode_0.acc_seg: 91.8474  decode_1.pointloss_ce: 0.2439  decode_1.acc_point: 70.2692
# 04/22 15:10:00 - mmengine - INFO - Iter(train) [19180/30000]  lr: 8.9352e-03  eta: 2:48:40  time: 0.8595  data_time: 0.0471  memory: 6078  loss: 0.3305  decode_0.loss_ce: 0.1213  decode_0.acc_seg: 95.6669  decode_1.pointloss_ce: 0.2091  decode_1.acc_point: 85.4813
# 04/22 15:10:10 - mmengine - INFO - Iter(train) [19190/30000]  lr: 8.9346e-03  eta: 2:48:33  time: 0.9655  data_time: 0.1128  memory: 6078  loss: 0.3703  decode_0.loss_ce: 0.1384  decode_0.acc_seg: 93.0426  decode_1.pointloss_ce: 0.2319  decode_1.acc_point: 76.4574
# 04/22 15:10:19 - mmengine - INFO - Iter(train) [19200/30000]  lr: 8.9341e-03  eta: 2:48:17  time: 0.8579  data_time: 0.0506  memory: 6078  loss: 0.3808  decode_0.loss_ce: 0.1413  decode_0.acc_seg: 93.9902  decode_1.pointloss_ce: 0.2395  decode_1.acc_point: 79.0937
# 04/22 15:10:28 - mmengine - INFO - Iter(train) [19210/30000]  lr: 8.9335e-03  eta: 2:48:10  time: 0.9684  data_time: 0.1192  memory: 6078  loss: 0.3710  decode_0.loss_ce: 0.1453  decode_0.acc_seg: 92.2894  decode_1.pointloss_ce: 0.2257  decode_1.acc_point: 74.9404
# 04/22 15:10:37 - mmengine - INFO - Iter(train) [19220/30000]  lr: 8.9329e-03  eta: 2:47:55  time: 0.8654  data_time: 0.0514  memory: 6078  loss: 0.3602  decode_0.loss_ce: 0.1371  decode_0.acc_seg: 93.6514  decode_1.pointloss_ce: 0.2231  decode_1.acc_point: 76.4233
# 04/22 15:10:47 - mmengine - INFO - Iter(train) [19230/30000]  lr: 8.9324e-03  eta: 2:47:48  time: 0.9665  data_time: 0.1032  memory: 6078  loss: 0.3780  decode_0.loss_ce: 0.1407  decode_0.acc_seg: 93.9496  decode_1.pointloss_ce: 0.2374  decode_1.acc_point: 77.5326
# 04/22 15:10:55 - mmengine - INFO - Iter(train) [19240/30000]  lr: 8.9318e-03  eta: 2:47:32  time: 0.8586  data_time: 0.0496  memory: 6078  loss: 0.3757  decode_0.loss_ce: 0.1368  decode_0.acc_seg: 94.2012  decode_1.pointloss_ce: 0.2389  decode_1.acc_point: 80.9128
# 04/22 15:11:05 - mmengine - INFO - Iter(train) [19250/30000]  lr: 8.9312e-03  eta: 2:47:28  time: 0.9920  data_time: 0.1346  memory: 6078  loss: 0.3633  decode_0.loss_ce: 0.1270  decode_0.acc_seg: 94.9712  decode_1.pointloss_ce: 0.2363  decode_1.acc_point: 80.9216
# 04/22 15:11:14 - mmengine - INFO - Iter(train) [19260/30000]  lr: 8.9307e-03  eta: 2:47:12  time: 0.8606  data_time: 0.0542  memory: 6078  loss: 0.3511  decode_0.loss_ce: 0.1256  decode_0.acc_seg: 94.2105  decode_1.pointloss_ce: 0.2255  decode_1.acc_point: 77.3680
# 04/22 15:11:23 - mmengine - INFO - Iter(train) [19270/30000]  lr: 8.9301e-03  eta: 2:47:06  time: 0.9750  data_time: 0.1173  memory: 6078  loss: 0.3735  decode_0.loss_ce: 0.1381  decode_0.acc_seg: 94.6109  decode_1.pointloss_ce: 0.2354  decode_1.acc_point: 81.2944
# 04/22 15:11:32 - mmengine - INFO - Iter(train) [19280/30000]  lr: 8.9296e-03  eta: 2:46:51  time: 0.8633  data_time: 0.0510  memory: 6078  loss: 0.3523  decode_0.loss_ce: 0.1313  decode_0.acc_seg: 94.1047  decode_1.pointloss_ce: 0.2209  decode_1.acc_point: 77.9522
# 04/22 15:11:42 - mmengine - INFO - Iter(train) [19290/30000]  lr: 8.9290e-03  eta: 2:46:45  time: 0.9790  data_time: 0.1281  memory: 6078  loss: 0.3798  decode_0.loss_ce: 0.1425  decode_0.acc_seg: 93.5411  decode_1.pointloss_ce: 0.2373  decode_1.acc_point: 79.1981
# 04/22 15:11:50 - mmengine - INFO - Iter(train) [19300/30000]  lr: 8.9284e-03  eta: 2:46:30  time: 0.8618  data_time: 0.0527  memory: 6078  loss: 0.4153  decode_0.loss_ce: 0.1518  decode_0.acc_seg: 94.3617  decode_1.pointloss_ce: 0.2635  decode_1.acc_point: 80.4677
# 04/22 15:12:00 - mmengine - INFO - Iter(train) [19310/30000]  lr: 8.9279e-03  eta: 2:46:22  time: 0.9548  data_time: 0.1025  memory: 6078  loss: 0.4016  decode_0.loss_ce: 0.1536  decode_0.acc_seg: 94.8685  decode_1.pointloss_ce: 0.2480  decode_1.acc_point: 81.5662
# 04/22 15:12:09 - mmengine - INFO - Iter(train) [19320/30000]  lr: 8.9273e-03  eta: 2:46:08  time: 0.8650  data_time: 0.0491  memory: 6078  loss: 0.4280  decode_0.loss_ce: 0.1568  decode_0.acc_seg: 91.6299  decode_1.pointloss_ce: 0.2713  decode_1.acc_point: 72.3313
# 04/22 15:12:18 - mmengine - INFO - Iter(train) [19330/30000]  lr: 8.9267e-03  eta: 2:46:00  time: 0.9560  data_time: 0.0963  memory: 6078  loss: 0.4001  decode_0.loss_ce: 0.1456  decode_0.acc_seg: 93.5456  decode_1.pointloss_ce: 0.2545  decode_1.acc_point: 75.4315
# 04/22 15:12:27 - mmengine - INFO - Iter(train) [19340/30000]  lr: 8.9262e-03  eta: 2:45:45  time: 0.8600  data_time: 0.0524  memory: 6078  loss: 0.4129  decode_0.loss_ce: 0.1511  decode_0.acc_seg: 94.8400  decode_1.pointloss_ce: 0.2618  decode_1.acc_point: 81.5976
# 04/22 15:12:37 - mmengine - INFO - Iter(train) [19350/30000]  lr: 8.9256e-03  eta: 2:45:40  time: 0.9854  data_time: 0.1317  memory: 6078  loss: 0.3682  decode_0.loss_ce: 0.1369  decode_0.acc_seg: 93.9905  decode_1.pointloss_ce: 0.2313  decode_1.acc_point: 77.9976
# 04/22 15:12:45 - mmengine - INFO - Iter(train) [19360/30000]  lr: 8.9250e-03  eta: 2:45:25  time: 0.8655  data_time: 0.0544  memory: 6078  loss: 0.3688  decode_0.loss_ce: 0.1411  decode_0.acc_seg: 94.5357  decode_1.pointloss_ce: 0.2278  decode_1.acc_point: 81.2364
# 04/22 15:12:55 - mmengine - INFO - Iter(train) [19370/30000]  lr: 8.9245e-03  eta: 2:45:18  time: 0.9617  data_time: 0.1115  memory: 6078  loss: 0.3782  decode_0.loss_ce: 0.1457  decode_0.acc_seg: 94.9800  decode_1.pointloss_ce: 0.2325  decode_1.acc_point: 77.2388
# 04/22 15:13:04 - mmengine - INFO - Iter(train) [19380/30000]  lr: 8.9239e-03  eta: 2:45:04  time: 0.8666  data_time: 0.0538  memory: 6078  loss: 0.3330  decode_0.loss_ce: 0.1289  decode_0.acc_seg: 93.8962  decode_1.pointloss_ce: 0.2041  decode_1.acc_point: 84.8173
# 04/22 15:13:13 - mmengine - INFO - Iter(train) [19390/30000]  lr: 8.9233e-03  eta: 2:44:56  time: 0.9510  data_time: 0.0917  memory: 6078  loss: 0.3562  decode_0.loss_ce: 0.1397  decode_0.acc_seg: 94.1686  decode_1.pointloss_ce: 0.2165  decode_1.acc_point: 83.2135
# 04/22 15:13:22 - mmengine - INFO - Iter(train) [19400/30000]  lr: 8.9228e-03  eta: 2:44:41  time: 0.8593  data_time: 0.0519  memory: 6078  loss: 0.3665  decode_0.loss_ce: 0.1474  decode_0.acc_seg: 94.8281  decode_1.pointloss_ce: 0.2191  decode_1.acc_point: 82.8197
# 04/22 15:13:31 - mmengine - INFO - Iter(train) [19410/30000]  lr: 8.9222e-03  eta: 2:44:33  time: 0.9565  data_time: 0.0943  memory: 6078  loss: 0.3610  decode_0.loss_ce: 0.1452  decode_0.acc_seg: 94.9766  decode_1.pointloss_ce: 0.2159  decode_1.acc_point: 82.5143
# 04/22 15:13:40 - mmengine - INFO - Iter(train) [19420/30000]  lr: 8.9216e-03  eta: 2:44:19  time: 0.8630  data_time: 0.0524  memory: 6078  loss: 0.4226  decode_0.loss_ce: 0.1525  decode_0.acc_seg: 94.8534  decode_1.pointloss_ce: 0.2701  decode_1.acc_point: 81.6958
# 04/22 15:13:50 - mmengine - INFO - Iter(train) [19430/30000]  lr: 8.9211e-03  eta: 2:44:12  time: 0.9678  data_time: 0.1198  memory: 6078  loss: 0.3864  decode_0.loss_ce: 0.1428  decode_0.acc_seg: 93.0996  decode_1.pointloss_ce: 0.2435  decode_1.acc_point: 78.6060
# 04/22 15:13:58 - mmengine - INFO - Iter(train) [19440/30000]  lr: 8.9205e-03  eta: 2:43:57  time: 0.8521  data_time: 0.0468  memory: 6078  loss: 0.3464  decode_0.loss_ce: 0.1298  decode_0.acc_seg: 93.2100  decode_1.pointloss_ce: 0.2166  decode_1.acc_point: 79.0577
# 04/22 15:14:08 - mmengine - INFO - Iter(train) [19450/30000]  lr: 8.9200e-03  eta: 2:43:49  time: 0.9572  data_time: 0.1011  memory: 6078  loss: 0.3080  decode_0.loss_ce: 0.1153  decode_0.acc_seg: 93.9185  decode_1.pointloss_ce: 0.1926  decode_1.acc_point: 79.3700
# 04/22 15:14:16 - mmengine - INFO - Iter(train) [19460/30000]  lr: 8.9194e-03  eta: 2:43:35  time: 0.8610  data_time: 0.0532  memory: 6078  loss: 0.2953  decode_0.loss_ce: 0.1153  decode_0.acc_seg: 95.7652  decode_1.pointloss_ce: 0.1800  decode_1.acc_point: 86.0562
# 04/22 15:14:26 - mmengine - INFO - Iter(train) [19470/30000]  lr: 8.9188e-03  eta: 2:43:28  time: 0.9615  data_time: 0.1153  memory: 6078  loss: 0.3008  decode_0.loss_ce: 0.1172  decode_0.acc_seg: 95.4765  decode_1.pointloss_ce: 0.1836  decode_1.acc_point: 86.1512
# 04/22 15:14:35 - mmengine - INFO - Iter(train) [19480/30000]  lr: 8.9183e-03  eta: 2:43:14  time: 0.8659  data_time: 0.0528  memory: 6078  loss: 0.3565  decode_0.loss_ce: 0.1336  decode_0.acc_seg: 95.0479  decode_1.pointloss_ce: 0.2229  decode_1.acc_point: 80.9506
# 04/22 15:14:44 - mmengine - INFO - Iter(train) [19490/30000]  lr: 8.9177e-03  eta: 2:43:05  time: 0.9433  data_time: 0.1003  memory: 6078  loss: 0.3558  decode_0.loss_ce: 0.1326  decode_0.acc_seg: 94.7414  decode_1.pointloss_ce: 0.2232  decode_1.acc_point: 80.2335
# 04/22 15:14:53 - mmengine - INFO - Iter(train) [19500/30000]  lr: 8.9171e-03  eta: 2:42:52  time: 0.8671  data_time: 0.0516  memory: 6078  loss: 0.3252  decode_0.loss_ce: 0.1236  decode_0.acc_seg: 95.2667  decode_1.pointloss_ce: 0.2016  decode_1.acc_point: 81.3400
# 04/22 15:14:53 - mmengine - INFO - Saving checkpoint at 19500 iterations
# 04/22 15:14:56 - mmengine - INFO - Iter(val) [  10/1158]    eta: 0:01:18  time: 0.0686  data_time: 0.0162  memory: 383
# 04/22 15:14:57 - mmengine - INFO - Iter(val) [  20/1158]    eta: 0:01:11  time: 0.0565  data_time: 0.0124  memory: 414
# 04/22 15:14:57 - mmengine - INFO - Iter(val) [  30/1158]    eta: 0:01:05  time: 0.0482  data_time: 0.0087  memory: 402
# 04/22 15:14:58 - mmengine - INFO - Iter(val) [  40/1158]    eta: 0:01:01  time: 0.0452  data_time: 0.0103  memory: 388
# 04/22 15:14:58 - mmengine - INFO - Iter(val) [  50/1158]    eta: 0:00:57  time: 0.0391  data_time: 0.0069  memory: 382
# 04/22 15:14:58 - mmengine - INFO - Iter(val) [  60/1158]    eta: 0:00:52  time: 0.0287  data_time: 0.0047  memory: 414
# 04/22 15:14:59 - mmengine - INFO - Iter(val) [  70/1158]    eta: 0:00:49  time: 0.0314  data_time: 0.0051  memory: 394
# 04/22 15:14:59 - mmengine - INFO - Iter(val) [  80/1158]    eta: 0:00:46  time: 0.0292  data_time: 0.0047  memory: 414
# 04/22 15:14:59 - mmengine - INFO - Iter(val) [  90/1158]    eta: 0:00:44  time: 0.0285  data_time: 0.0044  memory: 383
# 04/22 15:15:00 - mmengine - INFO - Iter(val) [ 100/1158]    eta: 0:00:42  time: 0.0290  data_time: 0.0046  memory: 454
# 04/22 15:15:00 - mmengine - INFO - Iter(val) [ 110/1158]    eta: 0:00:41  time: 0.0275  data_time: 0.0037  memory: 411
# 04/22 15:15:00 - mmengine - INFO - Iter(val) [ 120/1158]    eta: 0:00:39  time: 0.0288  data_time: 0.0038  memory: 414
# 04/22 15:15:00 - mmengine - INFO - Iter(val) [ 130/1158]    eta: 0:00:38  time: 0.0282  data_time: 0.0038  memory: 442
# 04/22 15:15:01 - mmengine - INFO - Iter(val) [ 140/1158]    eta: 0:00:37  time: 0.0291  data_time: 0.0036  memory: 417
# 04/22 15:15:01 - mmengine - INFO - Iter(val) [ 150/1158]    eta: 0:00:36  time: 0.0285  data_time: 0.0038  memory: 457
# 04/22 15:15:01 - mmengine - INFO - Iter(val) [ 160/1158]    eta: 0:00:35  time: 0.0271  data_time: 0.0037  memory: 424
# 04/22 15:15:02 - mmengine - INFO - Iter(val) [ 170/1158]    eta: 0:00:34  time: 0.0269  data_time: 0.0036  memory: 401
# 04/22 15:15:02 - mmengine - INFO - Iter(val) [ 180/1158]    eta: 0:00:34  time: 0.0276  data_time: 0.0041  memory: 383
# 04/22 15:15:02 - mmengine - INFO - Iter(val) [ 190/1158]    eta: 0:00:33  time: 0.0279  data_time: 0.0037  memory: 416
# 04/22 15:15:02 - mmengine - INFO - Iter(val) [ 200/1158]    eta: 0:00:32  time: 0.0277  data_time: 0.0041  memory: 383
# 04/22 15:15:03 - mmengine - INFO - Iter(val) [ 210/1158]    eta: 0:00:32  time: 0.0290  data_time: 0.0040  memory: 406
# 04/22 15:15:03 - mmengine - INFO - Iter(val) [ 220/1158]    eta: 0:00:31  time: 0.0286  data_time: 0.0038  memory: 436
# 04/22 15:15:03 - mmengine - INFO - Iter(val) [ 230/1158]    eta: 0:00:31  time: 0.0287  data_time: 0.0044  memory: 403
# 04/22 15:15:04 - mmengine - INFO - Iter(val) [ 240/1158]    eta: 0:00:30  time: 0.0286  data_time: 0.0040  memory: 416
# 04/22 15:15:04 - mmengine - INFO - Iter(val) [ 250/1158]    eta: 0:00:30  time: 0.0296  data_time: 0.0040  memory: 404
# 04/22 15:15:04 - mmengine - INFO - Iter(val) [ 260/1158]    eta: 0:00:29  time: 0.0282  data_time: 0.0043  memory: 461
# 04/22 15:15:04 - mmengine - INFO - Iter(val) [ 270/1158]    eta: 0:00:29  time: 0.0281  data_time: 0.0042  memory: 402
# 04/22 15:15:05 - mmengine - INFO - Iter(val) [ 280/1158]    eta: 0:00:28  time: 0.0293  data_time: 0.0046  memory: 402
# 04/22 15:15:05 - mmengine - INFO - Iter(val) [ 290/1158]    eta: 0:00:28  time: 0.0298  data_time: 0.0047  memory: 395
# 04/22 15:15:05 - mmengine - INFO - Iter(val) [ 300/1158]    eta: 0:00:27  time: 0.0283  data_time: 0.0040  memory: 462
# 04/22 15:15:06 - mmengine - INFO - Iter(val) [ 310/1158]    eta: 0:00:27  time: 0.0290  data_time: 0.0040  memory: 396
# 04/22 15:15:06 - mmengine - INFO - Iter(val) [ 320/1158]    eta: 0:00:26  time: 0.0297  data_time: 0.0047  memory: 385
# 04/22 15:15:06 - mmengine - INFO - Iter(val) [ 330/1158]    eta: 0:00:26  time: 0.0289  data_time: 0.0041  memory: 412
# 04/22 15:15:07 - mmengine - INFO - Iter(val) [ 340/1158]    eta: 0:00:26  time: 0.0310  data_time: 0.0058  memory: 414
# 04/22 15:15:07 - mmengine - INFO - Iter(val) [ 350/1158]    eta: 0:00:25  time: 0.0303  data_time: 0.0044  memory: 383
# 04/22 15:15:07 - mmengine - INFO - Iter(val) [ 360/1158]    eta: 0:00:25  time: 0.0319  data_time: 0.0055  memory: 462
# 04/22 15:15:07 - mmengine - INFO - Iter(val) [ 370/1158]    eta: 0:00:25  time: 0.0284  data_time: 0.0040  memory: 428
# 04/22 15:15:08 - mmengine - INFO - Iter(val) [ 380/1158]    eta: 0:00:24  time: 0.0289  data_time: 0.0047  memory: 383
# 04/22 15:15:08 - mmengine - INFO - Iter(val) [ 390/1158]    eta: 0:00:24  time: 0.0356  data_time: 0.0080  memory: 414
# 04/22 15:15:09 - mmengine - INFO - Iter(val) [ 400/1158]    eta: 0:00:24  time: 0.0491  data_time: 0.0114  memory: 461
# ...
# |          ribbon          |  0.0  |  0.0  |
# |          rivet           |  0.0  |  0.0  |
# |          ruffle          | 23.07 | 25.24 |
# |          sequin          |  0.0  |  0.0  |
# |          tassel          |  0.0  |  0.0  |
# +--------------------------+-------+-------+
# 04/22 18:10:36 - mmengine - INFO - Iter(val) [1158/1158]    aAcc: 93.9500  mIoU: 20.2400  mAcc: 25.0200  data_time: 0.0043  time: 0.0253
# CascadeEncoderDecoder(
#   (data_preprocessor): SegDataPreProcessor()
#   (backbone): ResNetV1c(
#     (stem): Sequential(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#       (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU(inplace=True)
#       (6): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (7): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): ReLU(inplace=True)
#     )
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): ResLayer(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'open-mmlab://resnet50_v1c'}
#   (neck): FPN(
#     (lateral_convs): ModuleList(
#       (0): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): ConvModule(
#         (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): ConvModule(
#         (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (3): ConvModule(
#         (conv): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (fpn_convs): ModuleList(
#       (0-3): 4 x ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   init_cfg={'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
#   (decode_head): ModuleList(
#     (0): FPNHead(
#       input_transform=multiple_select, ignore_index=255, align_corners=False
#       (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#       (conv_seg): Conv2d(128, 47, kernel_size=(1, 1), stride=(1, 1))
#       (scale_heads): ModuleList(
#         (0): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#         )
#         (1): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Upsample()
#         )
#         (2): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Upsample()
#           (2): ConvModule(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (3): Upsample()
#         )
#         (3): Sequential(
#           (0): ConvModule(
#             (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): Upsample()
#           (2): ConvModule(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (3): Upsample()
#           (4): ConvModule(
#             (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (5): Upsample()
#         )
#       )
#     )
#     init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'conv_seg'}}
#     (1): PointHead(
#       input_transform=multiple_select, ignore_index=255, align_corners=False
#       (loss_decode): CrossEntropyLoss(avg_non_ignore=False)
#       (fcs): ModuleList(
#         (0-2): 3 x ConvModule(
#           (conv): Conv1d(303, 256, kernel_size=(1,), stride=(1,))
#           (activate): ReLU()
#         )
#       )
#       (fc_seg): Conv1d(303, 47, kernel_size=(1,), stride=(1,))
#     )
#     init_cfg={'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_seg'}}
#   )
# )
